# %%
import numpy as np
import pandas as pd
df = pd.read_excel("Downloads\\Colab Notebooks-20241019T120126Z-001\\Colab Notebooks\\flipkart_reviews(final)(renew).xlsx")

# %%
df1 = df.head(5)
df1.columns = df1.columns.str.strip()
occupation_index = df1.columns.get_loc('Occupation')
df1 = df1.iloc[:, :occupation_index + 1]
df1
# Out:
#               Reviews for Samsung Galaxy Watch Ultra           Age Gender  \
# 0  It's much better than watch ultra 2. Value for...         25-34      M
# 1  Value for money ? No.\nQuality: built quality ...         35-44      M
# 2             Just one word.......awesome. go for it         18-24      M
# 3  Android Users other than that of Samsung, you ...  55 and above      M
# 4                                      Exalent watch  55 and above      F
#
#                    Location            Occupation
# 0   Tirunelveli, Tamil Nadu  Working Professional
# 1      Bengaluru, Karnataka  Working Professional
# 2  Navi Mumbai, Maharashtra               Student
# 3                 New Delhi               Retired
# 4    Devanahalli, Karnataka               Retired

# %%
df2 = df[8:18]
df2.columns = df2.columns.str.strip()
occupation_index = df2.columns.get_loc('Occupation')
df2 = df2.iloc[:, :occupation_index + 1]
df2
# Out:
#                Reviews for Samsung Galaxy Watch Ultra           Age Gender  \
# 8   Watch luks amazing, strap is very comfortable,...      Under 18      M
# 9   Looks premium N classy. Almost accurate data n...         45-54      M
# 10  It's a two day usage review Premium look and q...         18-24      M
# 11  I have upgraded from watch 4 and compared to t...  55 and above      M
# 12  In terms of feature it has all the feature you...  55 and above      M
# 13  Battery is disappointing as it discharge withi...      Under 18      M
# 14  Review after 3 weeks:\n1. Poor battery life (1...         35-44      M
# 15  Excellent watch by Samsung. Pairs perfectly wi...         25-34      M
# 16                         Battery very fast decrease         18-24      M
# 17  I love Samsung watch barring it's battery life...      Under 18      F
#
#                     Location            Occupation
# 8     Araria District, Bihar               Student
# ...
