# %%
import numpy as np
import pandas as pd
df1 = pd.read_excel("C:\\Users\\tanwa\\Downloads\\Final Trend analysis(final renew).xlsx")

# %%
df = df1.head(416)
df
# Out:
#                         Reviews for Samsung Galaxy Watch            Age  \
# 0    It's much better than watch ultra 2. Value for...            25-34
# 1    Value for money ? No.\nQuality: built quality ...            35-44
# 2               Just one word.......awesome. go for it            18-24
# 3    Android Users other than that of Samsung, you ...     55 and above
# 4                                        Exalent watch     55 and above
# ..                                                 ...              ...
# 411  Best smartwatch in this time. Many more option...            25-34
# 412                                            Not bad            18-24
# 413  Nice product with lot of features but battery ...     55 and above
# 414  Samsung Galaxy Watch 4 Classic LTE: A Comprehe...            25-34
# 415  One of Best Purchase , You Are buying a friend...     55 and above
#
#     Gender                   Location            Occupation      Month  Year  \
# ...

# %%
df2 = df1[418:750]
df2.columns = df1.columns.str.strip()
df2.reset_index(drop=True, inplace=True)
df2.columns = df2.iloc[0]  
df2 = df2[1:].reset_index(drop=True) 
df2
# Out:
# 0                             Reviews for Apple Watch            Age Gender  \
# 0    The product is a beast ! Feels premium and is ...         25-34      F
# 1    Apple watch Ultra 2 is a beast when it comes t...  55 and above      M
# 2    Very good product nice Apple Watch thanks flip...         25-34      M
# 3                                    Very nice product         35-44      M
# 4    Nothing to say more , its just a beast in its ...         45-54      F
# ..                                                 ...           ...    ...
# 326  I ordered watches for all my family members..\...         35-44      M
# 327  I ordered watches for all my family members..\...         35-44      M
# 328                                      Awesome Watch  55 and above      F
# 329                          Looks premium and special         25-34      M
# 330                                     Battery to bad      Under 18      F
#
# ...

# %%
df3 = df1[752:1305]
df3.columns = df1.columns.str.strip()
df3.reset_index(drop=True, inplace=True)
df3.columns = df3.iloc[0]  
df3 = df3[1:].reset_index(drop=True) 
df3
# Out:
# 0                                    Reviews for Noise           Age Gender  \
# 0    I'm in love with thi product thnks filpkart fo...         25-34      F
# 1                                              Loved 😍         45-54      F
# 2    VERY NICE 👍 WATCH I'M IMPRESSED 😊 GOOD SERVICE...  55 and above      M
# 3    Superb Watch Under This price Range.......\nVa...         45-54      M
# 4                                               Nice 👍      Under 18      M
# ..                                                 ...           ...    ...
# 547                                     Waste of money      Under 18      F
# 548                                 Great experience!!         25-34      F
# 549                                   Product was good         25-34      M
# 550                                               Good  55 and above      M
# 551                                       Good morning         25-34      F
#
# ...

# %%
df4 = df1[1307:1377]
df4.columns = df1.columns.str.strip()
df4.reset_index(drop=True, inplace=True)
df4.columns = df4.iloc[0]  
df4 = df4[1:].reset_index(drop=True) 
df4
# Out:
# 0                           Reviews for OnePlus Watch           Age Gender  \
# 0   Good but with flaws\nI have been a samsung wat...         25-34      M
# 1                                           Loved it.         18-24      F
# 2   My first smart watch\nWatch was awesome and su...         45-54      M
# 3                             Perfect😍\nBest in Class         35-44      M
# 4   In one word...\n\nwe can say,\n\nunbelievable..!!  55 and above      M
# ..                                                ...           ...    ...
# 64                                             Don't       Under 18      M
# 65  I don’t personally use wearable health devices...         18-24      M
# 66    Helpful for tracking steps and quality of sleep         18-24      M
# 67                                      Well \n\n\n\n         35-44      M
# 68                                         It's good.  55 and above      M
#
# ...

# %%
df5 = df1[1379:1661]
df5.columns = df1.columns.str.strip()
df5.reset_index(drop=True, inplace=True)
df5.columns = df5.iloc[0]  
df5 = df5[1:].reset_index(drop=True) 
df5
# Out:
# 0                              Reviews for Redmi Watch    Age Gender  \
# 0    Watch is big in size but looks professional. B...  35-44      F
# 1    Best smartwatch in this budget with calling an...  45-54      M
# 2    The size is too big and it can be slim too. If...  35-44      M
# 3    Everything is perfect.\nBest of budget smartwa...  18-24      F
# 4    Battery back up is superb\nConnectivity is als...  35-44      M
# ..                                                 ...    ...    ...
# 276                            Such a wonderful watch!  18-24      F
# 277                                                 Nc  18-24      M
# 278  It is a nice working design with a good lookin...  45-54      F
# 279   I use to measure heart beats, distance I walked.  35-44      F
# 280  good experience , helps to keep somewhat track...  18-24      F
#
# 0                        Location            Occupation      Month  Year  \
# ...

# %%
df6 = df1[1663:2016]
df6.columns = df1.columns.str.strip()
df6.reset_index(drop=True, inplace=True)
df6.columns = df6.iloc[0]  
df6 = df6[1:].reset_index(drop=True) 
df6
# Out:
# 0                             Reviews for Mi SmartBand           Age Gender  \
# 0                          Good product at this price.  55 and above      M
# 1    Best product and it is the original MI Smart B...         25-34      M
# 2                                         Nice product         45-54      F
# 3    Really great product I love very much, plzz go...         35-44      F
# 4                                   Best ...Smooth ...         45-54      M
# ..                                                 ...           ...    ...
# 347  awesome product. has a good and soft strap and...         35-44      M
# 348  amazing something accurate pedometer\nheart ra...         45-54      M
# 349  this is the best and excellent work I am happy...         45-54      F
# 350  I was thinking of getting a smart watch for a ...      Under 18      F
# 351  Works perfectly! Amazing. Best thing is shows ...         45-54      F
#
# ...

# %%
df7 = df1[2018:2089]
df7.columns = df1.columns.str.strip()
df7.reset_index(drop=True, inplace=True)
df7.columns = df7.iloc[0]  
df7 = df7[1:].reset_index(drop=True) 
df7
# Out:
# 0                      Reviews for Google Pixel Watch       Age Gender  \
# 0   I have been using Pixel Watch 2 from the last ...     25-34      M
# 1   Yet another overpriced amazing looking unique ...     45-54      F
# 2   The watch looks very stylish and the features ...  Under 18      F
# 3                                        Cool 😎 watch     45-54      M
# 4   The amoled display and overall built are absol...  Under 18      M
# ..                                                ...       ...    ...
# 65                                            Perfect     25-34      F
# 66                                 Top Notch!!!!!! ❤️     35-44      F
# 67  Costly, but totally worth it. The AMOLED displ...     45-54      F
# 68  This is the best watch from Google and is mile...  Under 18      M
# 69                                        Great watch     18-24      M
#
# 0                    Location            Occupation      Month  Year Quarter
# ...

# %%
df8 = df1[2091:2673]
df8.columns = df1.columns.str.strip()
df8.reset_index(drop=True, inplace=True)
df8.columns = df8.iloc[0]  
df8 = df8[1:].reset_index(drop=True) 
df8
# Out:
# 0                                     Reviews for Boat           Age Gender  \
# 0    Boat smart watch is an impressive wearable dev...      Under 18      F
# 1                       Product is very good 😊 love it         35-44      F
# 2    My friend tell about this it was so good produ...         18-24      F
# 3    U have to charge Daily Or Every 2 Days . . . B...         35-44      M
# 4                                    Thnkss flipkart..         45-54      F
# ..                                                 ...           ...    ...
# 576                                              Noice         35-44      F
# 577  Cheating, there is no 100+cloud watch faces on...  55 and above      M
# 578                                          Very nice         18-24      M
# 579           Battery full charge working only 8 hours      Under 18      M
# 580               Bellt size and bellt very bad colety         35-44      M
#
# ...

# %%
df9 = df1[2675:3368]
df9.columns = df1.columns.str.strip()
df9.reset_index(drop=True, inplace=True)
df9.columns = df9.iloc[0]  
df9 = df9[1:].reset_index(drop=True) 
df9
# Out:
# 0                                 Reviews for Fastrack       Age Gender  \
# 0                 Value for money ..thank you Fastrack     25-34      M
# 1                                         Nice quality     25-34      M
# 2                                         Good product     25-34      M
# 3    Thank you Flipkart ❣️\nBest Smartwatch for use...     35-44      M
# 4                                         Nice product     35-44      M
# ..                                                 ...       ...    ...
# 687                                          Awesome 👍     45-54      M
# 688                          Product is good I love it  Under 18      F
# 689                   Good quality thanks for flipkart     45-54      F
# 690                                             Good p     18-24      M
# 691                       This watch is very beautiful     25-34      F
#
# 0                                   Location            Occupation      Month  \
# ...

# %%
df10 = df1[3370:4284]
df10.columns = df1.columns.str.strip()
df10.reset_index(drop=True, inplace=True)
df10.columns = df10.iloc[0]  
df10 = df10[1:].reset_index(drop=True) 
df10
# Out:
# 0                                Reviews for Fireboltt           Age Gender  \
# 0    I am using it from a day. It's really good loo...         25-34      M
# 1    Nice watch' good deal thnx Flipkart\nI need on...  55 and above      M
# 2    Very nice, I have bought for child, he so mush...         25-34      F
# 3                                 Superb i m impressed         25-34      F
# 4                                             Loved it         35-44      M
# ..                                                 ...           ...    ...
# 908  We can't call anyone through Bluetooth.But we ...         45-54      F
# 909                                         Good watch      Under 18      M
# 910                                Very nice ✅✅product         18-24      M
# 911                  This to good for the money I paid      Under 18      M
# 912                                    Best in quality         25-34      M
#
# ...

# %%
df11 = df1[4286:4588]
df11.columns = df1.columns.str.strip()
df11.reset_index(drop=True, inplace=True)
df11.columns = df11.iloc[0]  
df11 = df11[1:].reset_index(drop=True) 
df11
# Out:
# 0                                   Reviews for FitBit           Age Gender  \
# 0    I wasn't a great fan of activity monitors but ...         25-34      F
# 1    My wife wanted a smart watch which could guess...  55 and above      M
# 2    Overall the look and the features are good, ho...         35-44      F
# 3    Every day I am falling in love with this versa...         25-34      F
# 4                                    wonderful product  55 and above      M
# ..                                                 ...           ...    ...
# 296                            Very good smart watch..         35-44      M
# 297                                              Great  55 and above      F
# 298                    Excellent watch..\nWorth to buy      Under 18      F
# 299  please don't go for versa 3. The watch softwar...         18-24      F
# 300    Helpful way to keep a track on health everyday          25-34      F
#
# ...

# %%
df12 = df1[4590:5289]
df12.columns = df1.columns.str.strip()
df12.reset_index(drop=True, inplace=True)
df12.columns = df12.iloc[0]  
df12 = df12[1:].reset_index(drop=True) 
df12
# Out:
# 0                                    Reviews for Boult           Age Gender  \
# 0    Awesome watch with overloaded features. And it...         25-34      M
# 1                        Good product and best Quality         25-34      M
# 2    Value For Money Product, But Battary Drain Ver...         25-34      M
# 3                              Nice watch very happy 😊  55 and above      F
# 4    Look wise very good features is decent as othe...      Under 18      F
# ..                                                 ...           ...    ...
# 693                                             Nice 👍         45-54      M
# 694                                    Good product...         35-44      M
# 695                   Product is very good 👍😊\nHappy 😊         45-54      M
# 696                                          Very good  55 and above      F
# 697                                               Good         35-44      M
#
# ...

# %%
df13 = df1[5291:5886]
df13.columns = df1.columns.str.strip()
df13.reset_index(drop=True, inplace=True)
df13.columns = df13.iloc[0]  
df13 = df13[1:].reset_index(drop=True) 
df13
# Out:
# 0                                  Reviews for Amazfit           Age Gender  \
# 0    It's not a watch but a sophisticated / premium...         18-24      M
# 1    Just awesome\nDisplay is very nice\nNo lagging...  55 and above      M
# 2    Superb watch this watch is amazing\nRealme and...         18-24      M
# 3    Bestest smartwatch ⌚ ever 😍\nI really liked it...         25-34      M
# 4    I love this watch ❤️❤️I buy for my sister she ...         25-34      F
# ..                                                 ...           ...    ...
# 589  One of the best smart watch. Top notch quality...         45-54      M
# 590  When I bought it my first impression was good,...  55 and above      M
# 591  I liked the product. Straps should be of leath...         35-44      M
# 592                       Style and Performance watch.         35-44      F
# 593  Loving the classic watch design... most value ...  55 and above      M
#
# ...

# %%
df14 = df1[5888:6330]
df14.columns = df1.columns.str.strip()
df14.reset_index(drop=True, inplace=True)
df14.columns = df14.iloc[0]  
df14 = df14[1:].reset_index(drop=True) 
df14
# Out:
# 0                                   Reviews for Fossil           Age Gender  \
# 0    I can say it's a well built good looking watch...         25-34      M
# 1    Its a good looking watch with all features tha...  55 and above      M
# 2    Pretty decent watch! Good for function & party...         35-44      M
# 3    i m using this product last 4 months. after re...         25-34      M
# 4    Watch is beautiful and elegant. Run hours is a...      Under 18      M
# ..                                                 ...           ...    ...
# 436  After use of more than 1 year watch is OK... l...      Under 18      M
# 437  Never ever buy any fossil smart product. Waste...         25-34      F
# 438                                    Loved the watch  55 and above      M
# 439  Overall a great buy but battery is so poor nd ...  55 and above      M
# 440                                   Very bad product      Under 18      M
#
# ...

# %%
df.to_csv("df.csv", index=False)
df2.to_csv("df2.csv", index=False)
df3.to_csv("df3.csv", index=False)
df4.to_csv("df4.csv", index=False)
df5.to_csv("df5.csv", index=False)
df6.to_csv("df6.csv", index=False)
df7.to_csv("df7.csv", index=False)
df8.to_csv("df8.csv", index=False)
df9.to_csv("df9.csv", index=False)
df10.to_csv("df10.csv", index=False)
df11.to_csv("df11.csv", index=False)
df12.to_csv("df12.csv", index=False)
df13.to_csv("df13.csv", index=False)
df14.to_csv("df14.csv", index=False)
